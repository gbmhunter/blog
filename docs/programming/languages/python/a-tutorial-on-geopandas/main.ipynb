# %%
import os
from pathlib import Path

import geopandas
import matplotlib.pyplot as plt

SCRIPT_DIR = Path(os.getcwd())

# %%
world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))
world.plot(figsize=(10,15))
plt.tight_layout()
# plt.savefig(SCRIPT_DIR / 'geopandas-plotted-earth.png')

# %%
os.getcwd()
# Out:
# '/Users/ghunter/code/blog/content/programming/languages/python/a-tutorial-on-geopandas'
